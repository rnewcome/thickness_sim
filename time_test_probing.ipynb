# %%
from math import pi
import thickness_sim

# %%
net = thickness_sim.NetModel()

# %%
net.create_net(250, 250, pi/4, pi/4, 40, 1, .03)
net.indie_variator(1, .001)
net.outdie_variator(1, .001)
net.plot_2d_contour()

# %%
net.add_probe_line_across(10)

# %%
net.plot_2d_contour()

# %%
# %%timeit
net.execute_probe()
# Out:
# 15.8 ms ± 553 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)
